# %%
import mysql.connector as conn
mydb = conn.connect(host= 'localhost', user = 'root', passwd = 'Amrita@1994', database = 'practice')

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")
cursor.fetchall()
# Out:
# [('car_dataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pharma',),
#  ('pharma2',),
#  ('practice',),
#  ('program',),
#  ('sys',),
#  ('test_amrita',)]

# %%
#Q1)Write an SQL query to print the FIRST_NAME from Worker table after removing white spaces from the right side.
cursor.execute("select rtrim(name) as trimmed_name from practice.worker")
cursor.fetchall()
# Out:
# [('Gregory Bridges',),
#  ('',),
#  ('William Allen',),
#  ('Tonya Woods',),
#  ('',),
#  ('Vacant',),
#  ('Alexis R. Graves',),
#  ('Marqui Barnes',),
#  ('Ravoyne Payton',),
#  ('Kent Politsch',),
#  ('',),
#  ('Barbara McLean',),
#  ('Jennifer Weatherly',),
#  ('',),
#  ('Vacant',),
#  ('Arianne Perkins',),
#  ('',),
#  ('Vacant',),
#  ('Rochelle Foster',),
#  ('',),
#  ('Ellen Dougherty',),
#  ('Raynell Lazier',),
#  ('',),
#  ('Vacant',),
#  ('Lakita Ross',),
#  ('Lakita Ross',),
#  ('Dexter Thomas',),
#  ('Brenda V. Seegars',),
#  ('',),
#  ('Brenda V. Seegars',),
#  ('Cheri Alsobrook/Sandy François',),
#  ('Sandy François',),
#  ('Cheri Alsobrook',),
#  ('Patrick McLoughlin',),
#  ('',),
#  ('Philip Buchan',),
#  ('Julie Hetrick',),
#  ('Julie Hetrick',),
#  ('Andrew Perry',),
#  ('Iris Roseboro',),
#  ('Cheri Alsobrook',),
#  ('Cheri Alsobrook',),
#  ('Alexis R. Graves',),
#  ('Marqui Barnes',),
#  ('Ravoyne Payton',),
#  ('Carl-Martin Ruiz',),
#  ('Samantha Jones',),
# ...

# %%
#Q-2. Write an SQL query that fetches the unique values of DEPARTMENT from Worker table and prints its length.
cursor.execute("select department, length(department) from practice.worker")
cursor.fetchall()
# Out:
# [('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
#  ('Department of Agriculture', 25),
# ...

# %%
#Q-3. Write an SQL query to fetch nth max salaries from a table.
cursor.execute("select max(salary) from practice.worker")
cursor.fetchall()
